# %% [markdown]
# # Interface
# #### Selecionar opção diferente das  possíveis

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 14:00:21
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 5
# Ending Program...
# Done.

# %%
# Criar Estudo
#### Selecionar opção diferente das  possíveis

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 14:04:48
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 1
# => Selected : Create a study
#
# ===============
#  Study Creator
# ===============
#
# Enter study path: asdfas
# Enter study name: asdfafd
# Enter sample size: 5
# Error: Invalid path.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 14:12:45
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 1
# => Selected : Create a study
#
# ===============
#  Study Creator
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Enter study name: proj01
# Enter sample size: 5
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT1
# 1
# Add Case (Name):c1
# Case Template File:asdfasdfa
# Error 4: File/Path not found.
# Case "c1" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT1
# 1
# Add Case (Name):c1
# Case Template File:E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model.dat
# Error 1: name already used.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT4
# 4
# Remove Case (Name):c1
# Case "c1" sucessfully removed.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT1
# 1
# Add Case (Name):c1
# Case Template File:E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model.dat
# Case "c1" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT1
# 1
# Add Case (Name):c2
# Case Template File:E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model2.dat
# Case "c2" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT1
# 1
# Add Case (Name):c3
# Case Template File:E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model.dat
# Error 3: #Cases greater than 2.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj01
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = []
# Objective Functions = []
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT2
# 2
# Parameter Distribuition:
# 1: Uniform
# 2: Normal
# 3: Truncated Normal
# 4: Lognormal
# otherwise: Return
# 1
# Parameter Name:P1
# min = 0
# max = 1
# Parameter "P1" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT2
# 2
# Parameter Distribuition:
# 1: Uniform
# 2: Normal
# 3: Truncated Normal
# 4: Lognormal
# otherwise: Return
# 2
# Parameter Name:p2
# mean = 0
# std = 1
# Parameter "p2" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT2
# 2
# Parameter Distribuition:
# 1: Uniform
# 2: Normal
# 3: Truncated Normal
# 4: Lognormal
# otherwise: Return
# 3
# Parameter Name:p1
# mean = 0
# std = 0
# min = 0
# max = 0
# Parameter "p1" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT2
# 2
# Parameter Distribuition:
# 1: Uniform
# 2: Normal
# 3: Truncated Normal
# 4: Lognormal
# otherwise: Return
# 4
# Parameter Name:p1
# mean = 0
# std = 0
# Error 1: name already used.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj01
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = ['P1', 'p2', 'p1']
# Objective Functions = []
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT3
# 3
# OF Type:
# 1: Cumulative Oil
# 2: Cumulative Water
# otherwise: Return
# 1
# Add OF (Name):np
# Initial Time:0
# End Time:120
# Delta? (0 = False )0
# False
# Objective Function "np" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT3
# 3
# OF Type:
# 1: Cumulative Oil
# 2: Cumulative Water
# otherwise: Return
# 1
# Add OF (Name):np
# Initial Time:0
# End Time:120
# Delta? (0 = False )0
# False
# Error 1: name already used.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj01
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = ['P1', 'p2', 'p1']
# Objective Functions = ['np']
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT3
# 3
# OF Type:
# 1: Cumulative Oil
# 2: Cumulative Water
# otherwise: Return
# 2
# Add OF (Name):wp
# Initial Time:0
# End Time:120
# Delta? (0 = False )0
# False
# Objective Function "wp" sucessfully added.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT5
# 5
# Remove Parameter (Name):p1
# Parameter "p1" sucessfully removed.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT4
# 4
# Remove Case (Name):p1
# Error 2: name not found.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT4
# 4
# Remove Case (Name):asdfasfa
# Error 2: name not found.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj01
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = ['P1', 'p2']
# Objective Functions = ['np', 'wp']
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT6
# 6
# Remove OF (Name):wp
# Objective Function "wp" sucessfully removed.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT5
# 5
# Remove Parameter (Name):asdfsaf
# Error 2: name not found.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj01
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = ['P1', 'p2']
# Objective Functions = ['np']
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT8
# 8
# Study Saved!!!
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj01
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = ['P1', 'p2']
# Objective Functions = ['np']
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT4
# 4
# Remove Case (Name):c2
# Case "c2" sucessfully removed.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT5
# 5
# Remove Parameter (Name):p2
# Parameter "p2" sucessfully removed.
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT9
# 9
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# otherwise: EXIT99
# 99

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 14:51:36
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 1
# => Selected : Create a study
#
# ===============
#  Study Creator
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Enter study name: proj02
# Enter sample size: 5
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 99
# 99
# Ending Program...
# Done.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 14:58:41
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 1
# => Selected : Create a study
#
# ===============
#  Study Creator
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Enter study name: proj02
# Enter sample size: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model.dat
# Error 7: Value must be integer.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 0
# 0
# Enter sample size: 0
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj02
# Sample size =  0
# Cases = []
# Parameters = []
# Objective Functions = []
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 8
# 8
# Study Saved!!!
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 2
# 2
# Parameter Distribuition:
# 1: Uniform
# 2: Normal
# 3: Truncated Normal
# 4: Lognormal
# otherwise: Return
# 1
# Parameter Name:1
# min = 2
# max = 2
# Parameter "1" sucessfully added.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj02
# Sample size =  0
# Cases = []
# Parameters = ['1']
# Objective Functions = []
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 8
# 8
# Study Incomplete. Please review before saving.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 99
# 99
# Ending Program...
# Done.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:06:49
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 1
# => Selected : Create a study
#
# ===============
#  Study Creator
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Enter study name: proj_ok
# Enter sample size: 5
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 1
# 1
# Add Case (Name):c1
# Case Template File:E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model.dat
# Case "c1" sucessfully added.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 1
# 1
# Add Case (Name):c2
# Case Template File:E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model2.dat
# Case "c2" sucessfully added.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 2
# 2
# Parameter Distribuition:
# 1: Uniform
# 2: Normal
# 3: Truncated Normal
# 4: Lognormal
# otherwise: Return
# 1
# Parameter Name:Prop1
# min = 0.1
# max = 0.4
# Parameter "Prop1" sucessfully added.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 3
# 3
# OF Type:
# 1: Cumulative Oil
# 2: Cumulative Water
# otherwise: Return
# 1
# Add OF (Name):np
# Initial Time:0
# End Time:3720
# Delta? (0 = False )1
# True
# Objective Function "np" sucessfully added.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 3
# 3
# OF Type:
# 1: Cumulative Oil
# 2: Cumulative Water
# otherwise: Return
# 2
# Add OF (Name):wp
# Initial Time:0
# End Time:3720
# Delta? (0 = False )1
# True
# Objective Function "wp" sucessfully added.
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 7
# 7
# Path =  E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
# Study Name =  proj_ok
# Sample size =  5
# Cases = ['c1', 'c2']
# Parameters = ['Prop1']
# Objective Functions = ['np', 'wp']
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 8
# 8
# Study Saved!!!
#
# ============
# Select an option:
# 0: Sample Size
# 1: Add Case
# 2: Add Parameter
# 3: Add Objective Function
# 4: Remove Case
# 5: Remove Parameter
# 6: Remove Objective Function
# 7: List Study
# 8: Save
# 99: EXIT
# 99
# 99
# Ending Program...
# Done.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:12:35
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 2
# => Selected : Run study
#
# ===============
#   Scheduler
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\asdfafdasadfafa
# Error 4: File/Path not found.
# Scheduler Error. Please review study.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:15:03
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 2
# => Selected : Run study
#
# ===============
#   Scheduler
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\dummy
# Error 4: File/Path not found.
# Scheduler Error. Please review study.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:16:28
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 2
# => Selected : Run study
#
# ===============
#   Scheduler
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\proj_ok
# Study is ready.
# Model proj_ok_c1_00001.dat: Simulation done.
# Model proj_ok_c2_00001.dat: Simulation done.
# Model proj_ok_c1_00002.dat: Simulation done.
# Model proj_ok_c2_00002.dat: Simulation done.
# Model proj_ok_c1_00003.dat: Simulation done.
# Model proj_ok_c2_00003.dat: Simulation done.
# Model proj_ok_c1_00004.dat: Simulation done.
# Model proj_ok_c2_00004.dat: Simulation done.
# Model proj_ok_c1_00005.dat: Simulation done.
# Model proj_ok_c2_00005.dat: Simulation done.
# Results saved!

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:21:10
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 2
# => Selected : Run study
#
# ===============
#   Scheduler
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\proj01
# Study is ready.
# Model proj01_c1_00001.dat: Simulation done.
# Scheduler Error. Please review study.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:24:51
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 2
# => Selected : Run study
#
# ===============
#   Scheduler
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\proj02
# Study is ready.
# Scheduler Error. Please review study.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:31:58
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 3
# => Selected : Analyse data
#
# ===============
#   Analysis
# ===============
#
# Enter study path: asdfasfd
# Results Error. Please review study.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:34:52
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 3
# => Selected : Analyse data
#
# ===============
#   Analysis
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\dummy
# Results Error. Please review study.

# %%
from classes.iua import IUA
ua01 = IUA()
ua01.initUA()
# Out:
# =================================
# Uncertainty Analysis Assistant
#            v1.0
# =================================
# Nov 27, 2021 - 15:44:06
#
#
# Select an option:
# 1: Create a study
# 2: Run study
# 3: Analyse data
# otherwise: Exit
# 3
# => Selected : Analyse data
#
# ===============
#   Analysis
# ===============
#
# Enter study path: E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\proj_ok
# Select analysis:
# 1: Histogram
# 2: Crossplot
# otherwhise: Exit
# 1
# Select Objective Function:
# ['np_c1', 'np_c2', 'np_Delta', 'wp_c1', 'wp_c2', 'wp_Delta']
# 0: np_c1
# 1: np_c2
# 2: np_Delta
# 3: wp_c1
# 4: wp_c2
# 5: wp_Delta
# 6
# Bins = 2
# Results Error. Please review study.

# %%
#E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects
#E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\proj_ok
#E:\Dropbox\CodeBunker\MESTRADO\S3_PFP\UAA\projects\reservoir\model.dat
